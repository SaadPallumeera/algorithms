# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Then, we run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
# install required libraries

# need scipy for writing wav files
# !pip install numpy matplotlib scipy

# import libraries
import math
import numpy as np
import matplotlib.pyplot as plt

# set figure size
plt.rcParams['figure.figsize'] = (5.0, 4.0)
plt.rcParams['font.size'] = 10
# %config InlineBackend.figure_format = 'retina'
# Out:
# Requirement already satisfied: numpy in /Users/admin/anaconda3/lib/python3.11/site-packages (1.24.4)
# Requirement already satisfied: matplotlib in /Users/admin/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: scipy in /Users/admin/anaconda3/lib/python3.11/site-packages (1.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/admin/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/admin/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from IPython.display import display_html, HTML

display_html(HTML('''
<style type="text/css">
  .instruction { background-color: yellow; font-weight:bold; padding: 3px; }
</style>
'''));
# Out:
# <style type="text/css">
#   .instruction { background-color: yellow; font-weight:bold; padding: 3px; }
# </style>

# %%
import ica
ica.hello()   # should print "Hello from ica.py!"
# Out:
# Hello from ica.py!

# %% [markdown]
# ## Load Data
#
# Let's load the sound data. This data contains mixed sound signals from multiple microphones.

# %%
from IPython.display import Audio, display

Fs = 11025  # sampling rate
def normalize(dat):
    return 0.99 * dat / np.max(np.abs(dat))

mix = np.loadtxt('data/ica_data.dat')
X = normalize(mix)
print(f'Loaded {X.shape[0] / Fs:.2f} seconds of audio with {X.shape[1]} microphones.')
# Out:
# Loaded 4.85 seconds of audio with 5 microphones.

# %%
for i in range(X.shape[1]):
    print(f'Microphone {i}:')
    display(Audio(X[:, i], rate=Fs))
# Out:
# Microphone 0:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Microphone 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Microphone 2:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Microphone 3:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Microphone 4:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Learning the filter *W*
#
# <p class="instruction">Implement the `ica.filter_grad()` function. </p>

# %% [markdown]
# This function computes the SGD update for ICA. This function will be used with `ica.unmixer` to find a filter `W` that we can use to unmix our sources `X`.
#
# The following code should take around up to 1~2 minutes to run.

# %%
# %%time

W = ica.unmixer(X)
print('W solution:\n', W)
# Out:
# Separating tracks ...
# working on alpha = 0.1
# working on alpha = 0.1
# working on alpha = 0.1
# working on alpha = 0.05
# working on alpha = 0.05
# working on alpha = 0.05
# working on alpha = 0.02
# working on alpha = 0.02
# working on alpha = 0.01
# working on alpha = 0.01
# working on alpha = 0.005
# working on alpha = 0.005
# working on alpha = 0.002
# working on alpha = 0.002
# working on alpha = 0.001
# working on alpha = 0.001
# W solution:
#  [[ 72.15081922  28.62441682  25.91040458 -17.2322227  -21.191357  ]
#  [ 13.45886116  31.94398247  -4.03003982 -24.0095722   11.89906179]
#  [ 18.89688784  -7.80435173  28.71469558  18.14356811 -21.17474522]
#  [ -6.0119837   -4.15743607  -1.01692289  13.87321073  -5.26252289]
#  [ -8.74061186  22.55821897   9.61289023  14.73637074  45.28841827]]
# CPU times: user 40.9 s, sys: 2.14 s, total: 43 s
# Wall time: 8.52 s

# %% [markdown]
# ## Unmixing with *W*
# <p class="instruction">Implement the `ica.unmix` function. </p>

# %% [markdown]
# Let's use our `W` to unmix our original sources `X`!

# %%
S = normalize(ica.unmix(X, W))

# %%
for i in range(X.shape[1]):
    print(f'Unmixed source {i}:')
    display(Audio(S[:, i], rate=Fs))
# Out:
# Unmixed source 0:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Unmixed source 1:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Unmixed source 2:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Unmixed source 3:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Unmixed source 4:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# How does it sound? Some overlap in sources may be present, but the sound sources should be pretty clearly separated. If you still hear some significant overlap, something is probably wrong in your implementation...

# %% [markdown]
# ## Saving the unmixed sources

# %% [markdown]
# ## Submission
#
# <p class="instruction">Report the *W* matrix you found in your final report. Submit this file along with ica.py to the autograder.</p>
# Make sure your unmixed source sound tracks are playable when you submit. These audio files will be embedded in the notebook and we may check these files when grading. You do <b>not</b> need to submit the saved unmixed `wav` tracks!
